# %%
import random
import numpy as np
import cec2017.functions as functions
import copy
import numpy_gpu as gpu

# %%
Dim = 10
NP = 100
bound = 100

# %%
X = np.random.uniform(low=-bound, high=bound, size=Dim)
X_min = X.min()
X_max = X.max()
X_list = np.empty([NP, Dim])
for i in range(NP):
    for j in range(Dim):
        X_list[i][j] = X_min + random.uniform(0, 1) * (X_max - X_min)

X_list
# Out:
# array([[-6.67997444e+01, -6.80582868e+01,  3.65223287e+01,
#          8.06593107e-01,  2.38042127e+01,  8.92311064e+01,
#          5.20521819e+01,  8.15330753e+01,  9.45700254e+00,
#          5.19380133e+01],
#        [ 4.98112281e+01, -9.06183831e+01,  7.08465146e+01,
#         -5.71894241e+01, -7.53401343e+01,  6.56394287e+01,
#          8.30553365e+00, -3.93334254e+01, -6.33765910e+01,
#         -4.01337791e+01],
#        [ 6.65508596e+01,  4.21865577e+01,  4.01688355e+00,
#         -7.94845288e+01, -6.08148216e+00,  1.97959577e+01,
#         -4.34328559e+01, -1.59681360e+01,  9.35128853e+00,
#         -9.24252171e+01],
#        [ 6.02790794e+01,  4.27245187e+01, -1.27248406e+00,
#         -4.55450709e+01,  6.83064194e+01, -8.10975127e-01,
#          8.68312900e+01, -6.69534076e+01, -5.43758824e+01,
#         -2.95582839e+00],
#        [-8.15333322e+01,  2.88235721e+01, -3.46634323e+01,
#          6.38001172e+01,  4.38284819e+01,  5.46625428e+01,
#          5.28870350e+01, -2.72161033e+01,  1.06537211e+00,
#         -8.37101908e+01],
#        [ 7.79599275e+01, -8.89712015e+01, -2.30970974e+01,
#          2.55158401e+01, -2.77520674e+01,  2.40418557e+01,
#         -9.28315433e+01,  7.82003757e+01, -2.17864476e+00,
#          8.10822958e+01],
#        [-9.61580951e+01, -1.06721975e+01, -8.98465416e+01,
#          5.56879656e+01, -6.87274829e+01,  2.20661770e+00,
#         -5.55583906e+01, -5.85620682e+01,  4.88525416e+01,
#          4.37336340e+01],
#        [-9.50182365e+01, -4.79919549e+01, -3.39008565e+01,
#         -4.34471859e+00, -6.95145927e+01,  7.98637021e+01,
#         -8.78394034e+01,  4.73521504e+01,  5.31216179e+01,
#          3.08986485e+00],
#        [ 6.68487023e+01,  8.78803243e+01,  7.46565010e+01,
#          5.42249497e+01,  7.44755342e+01, -6.53370821e+01,
#          5.63699718e+01, -9.57354605e+01,  1.72942680e+01,
#         -4.40964039e+01],
#        [-7.48874301e+00,  6.42329207e+01, -9.72860439e+01,
#         -8.73620587e+01, -8.55884102e+01, -5.24094400e+01,
#          8.93595009e+01, -8.73340134e+01,  5.77871980e+01,
#          5.83995535e+01],
#        [-4.12683494e+01,  8.64394435e+01,  6.01159569e+01,
#          8.12571246e+01,  2.26184644e+01, -1.00883311e+01,
#          3.78415367e+01, -6.24489715e+01,  6.63913012e+01,
#         -6.95385748e+01],
#        [-5.90409172e+01, -1.82687311e+01,  6.58537964e+01,
#         -7.88709246e+01,  8.21181922e+01, -1.02718912e+01,
#         -2.27245024e+01, -8.18195026e+01, -4.92768610e+01,
#          3.91128927e+01, -8.23129876e+01, -8.92297664e+01,
#          2.72546735e+01],
#        [-7.79040887e+01, -2.92083382e+01, -6.56215657e+01,
#          7.05156197e+01, -7.76141521e+01, -6.62607212e+01,
#         -2.70390966e+01, -1.10162486e+01,  5.40275607e+01,
#          5.42323514e+01],
#        [ 5.70353619e+01, -2.25826258e+01,  5.99835068e+01,
#         -7.43791646e+01, -1.05096921e+01, -6.75285874e+01,
#         -8.13018397e+00, -4.79134715e+01,  3.43826258e+01,
#          4.17369803e+01],
#        [ 7.57383854e+01,  2.18776988e+00, -8.50649368e+01,
#          5.67153459e+01, -6.45382320e+01, -1.57943134e+01,
#         -1.62067396e+01,  9.94994139e+00,  8.14580466e+01,
#          3.11324145e+01],
#        [-2.77376787e+01,  2.11332333e+01, -9.19951947e+01,
#         -2.69619216e+01, -3.69379464e+01, -6.69071884e+01,
#          6.15084254e+00, -1.40873655e+01,  1.86069764e+01,
#          4.04993396e+01],
#        [ 1.70999957e+00,  6.01120851e+01,  8.70687693e+01,
#          3.66882795e+01,  1.78511763e+01, -5.26491635e+01,
#          5.34187034e+01,  2.15265212e+01,  9.07906629e+00,
#         -2.05370474e+00],
#        [-1.15346425e+01,  5.28012559e+01, -8.52823077e+01,
#         -8.01340551e+01, -4.97444237e+01, -8.84679568e+01,
#         -1.40968854e+01, -9.71654806e+01, -5.41362322e+01,
#         -2.10123512e+01],
#        [ 1.76835691e+01,  2.75472667e+01,  2.39087554e+01,
#         -8.99295872e+01, -3.99678775e+01, -9.59378042e+01,
#         -3.15245216e+01,  1.07833049e+01,  3.63134645e+01,
#         -3.54111873e+01]])

# %%
""":parameter for DE"""
T_DE = 100
no = 5
CR = 0.9  # rate of crossover

""":parameter for MMS"""
mms_e = 0.000001
mms_F = 0.5

# %%
""":parameter k and F: for current/rand/1"""
k = 0.3
F = 0.5

# %%
""":parameter for crossoverSBX"""
sbx_n = 10

# %%
# f = functions.f1

# %%
def feas(x):
    if x.max() <= bound and x.min() >= -bound:
        return 1
    else:
        return 0

# %%
def select_better_fit(x1, x2, f):
    if f(x1) <= f(x2):
        return x1
    else:
        return x2

# %%
# def current_to_rand(x_list, r1, r2, r3, i):
#     return gpu.add(x_list[i], gpuk * gpu.subtract(x_list[r1], x_list[i]), F * gpu.subtract(x_list[r2], x_list[r3]))

# %%
def immsade(xx_list, r1, r2, r3):
    immsade_omega = random.uniform(0.7, 1.0)
    immsade_F = random.uniform(0.5, 0.8)
    v_delta = gpu.add(gpu.multiply(np.linspace(immsade_omega, immsade_omega, Dim), xx_list[r1]),
                     gpu.multiply(np.linspace(immsade_F, immsade_F, Dim), gpu.subtract(xx_list[r2], xx_list[r3])))
    v_delta = np.maximum(v_delta, -100)
    v_delta = np.minimum(v_delta, 100)
    return v_delta

# %%
def crossover_SBX(x_i, v_j, f):
    beta = 0
    while isinstance(beta, complex):
        sbx_rand = random.random()
        if sbx_rand <= 0.5:
            beta = (2 * sbx_rand) ** (1 / (1 + sbx_n))
        else:
            beta = (1 / (2 - sbx_n * 2)) ** (1 / (1 + sbx_n))

    c1 = 0.5 * gpu.add((1 + beta) * x_i, (1 - beta) * v_j)  # crossover
    c2 = 0.5 * gpu.add((1 - beta) * x_i, (1 + beta) * v_j)
    return select_better_fit(c1, c2, f)

# %%
def DE(f):
    x_list = copy.deepcopy(X_list)
    x_best = x_list[0]
    # print(x_list[0])

    t = 1
    while t <= T_DE:
        for i in range(NP):
            u_best = np.empty([Dim])
            for j in range(Dim):
                r_list = random.sample(range(NP), 5)
                for m in range(no):
                    while r_list[m] == i:
                        r_list[m] = random.randint(0, Dim - 1)

                v_j = np.empty([Dim])
                v_j = immsade(x_list, r_list[1], r_list[2], r_list[3])

                cr_rand = random.random()
                if cr_rand <= CR:
                    u_j = crossover_SBX(x_list[i], v_j, f)
                else:
                    u_j = x_list[i]

                if j == 0:
                    u_best = u_j
                else:
                    u_best = select_better_fit(u_best, u_j, f)

                if f(u_best) <= f(x_list[i]) and feas(u_best) == 1:
                    x_list[i] = u_best

                if f(x_list[i]) < f(x_best) and feas(x_list[i]) == 1:
                    x_best = x_list[i]

        t += 1
    return x_best

# %%
""":parameter: for AGDE"""
T_AGDE = 100

# %%
def index_of_X_best(xx_list, f):
    index = 0
    min_fit = f(xx_list[0])
    for i in range(len(xx_list)):
        if f(xx_list[i]) < min_fit:
            index = i
            min_fit = f(xx_list[i])
    return index


def index_of_X_worst(xx_list, f):
    index = 0
    max_fit = f(xx_list[0])
    for i in range(len(xx_list)):
        if f(xx_list[i]) > max_fit:
            index = i
            max_fit = f(xx_list[i])
    return index


def compare_max(delta):
    """
    lower bound
    :param delta: delta
    :return: turn into lower bound delta
    """

    em = np.linspace(-100, -100, Dim)
    delta = gpu.maximum(delta, em)
    return delta


def compare_min(delta):
    on = np.linspace(100, 100, Dim)
    delta = gpu.minimum(delta, on)
    # for i in range(len(delta)):
    #     delta[i] = min(delta[i], 1)
    return delta

def agde(xx_list, agde_F, agde_p, f):
    agde_NP = int(NP * agde_p)
    r_list = random.randint(agde_NP * 2 - 1, NP - 1)
    x_p_worst = xx_list[index_of_X_worst(xx_list[agde_NP: agde_NP * 2 - 1], f)]
    x_p_best = xx_list[index_of_X_best(xx_list[: agde_NP - 1], f)]
    v_delta = gpu.add(xx_list[r_list], gpu.multiply(np.linspace(agde_F, agde_F, Dim), gpu.subtract(x_p_best, x_p_worst)))
    return v_delta

# %%
def AGDE(f):
    xx_list = copy.deepcopy(X_list)
    x_best = xx_list[0]
    # print(xx_list[0])

    G = 0
    p_j = 0.5
    s_j_sum = 0
    while G <= T_AGDE:  # iteration of DE
        n_s_j = 0
        f_j = 1
        for i in range(NP):  # iteration of generation
            agde_F = random.uniform(0.1, 1)
            Cr = 0
            if G == 1:
                if random.uniform(0, 1) <= 0.5:
                    Cr = random.uniform(0.05, 0.15)
                else:
                    Cr = random.uniform(0.9, 1)
            else:
                if random.uniform(0, 1) <= p_j:
                    Cr = random.uniform(0.05, 0.15)
                else:
                    Cr = random.uniform(0.9, 1)
            j_random = random.randint(1, NP)

            u_best = np.empty([Dim])
            for j in range(Dim):
                vj = agde(xx_list, agde_F, p_j, f)
                vj = compare_max(vj)
                vj = compare_min(vj)
                if random.uniform(0, 1) < Cr or j == j_random:
                    u_j = crossover_SBX(xx_list[i], vj, f)
                else:
                    u_j = xx_list[i]

                if j == 0:
                    u_best = u_j
                else:
                    u_best = select_better_fit(u_best, u_j, f)

                if f(u_best) <= f(xx_list[i]) and feas(u_best) == 1:
                    xx_list[i] = u_best

                if f(xx_list[i]) < f(x_best) and feas(xx_list[i]) == 1:
                    x_best = xx_list[i]

        G += 1

        s_j = n_s_j / (n_s_j + f_j) + 0.01
        s_j_sum += s_j
        p_s_j = s_j / s_j_sum
        if (((G - 1) * p_j + p_s_j) / G) < 0.5:
            p_j = ((G - 1) * p_j + p_s_j) / G

    return x_best

# %%
""":parameter: for GSK"""
T_GSK = 100
GSK_p = 0.1
k_f = 0.01   # 0.5
k_r = 0.1   # 0.9
K = 10

# %%
def junior(xx_list, r, i, f):
    if random.uniform(0, 1) <= k_r:
        if f(xx_list[i]) > f(xx_list[r]):
            v_delta = gpu.add(xx_list[i],
                             gpu.multiply(np.linspace(k_f, k_f, Dim), gpu.add(gpu.subtract(xx_list[max(0, i - 1)], xx_list[min(NP - 1, i + 1)]),
                                          gpu.subtract(xx_list[r], xx_list[i]))))
        else:
            v_delta = gpu.add(xx_list[i],
                             gpu.multiply(np.linspace(k_f, k_f, Dim), gpu.add(gpu.subtract(xx_list[max(0, i - 1)], xx_list[min(NP - 1, i + 1)]),
                                          gpu.subtract(xx_list[i], xx_list[r]))))
    else:
        v_delta = xx_list[i]
    return v_delta


def senior(xx_list, i, D_junior, f):
    if random.uniform(0, 1) <= k_r:
        D_senior = NP - D_junior
        NP_1 = int(D_senior * GSK_p)
        r_list = random.randint(D_junior - 1 + NP_1 * 2, NP - 1)
        x_p_worst = xx_list[index_of_X_worst(xx_list[D_junior - 1 + NP_1: D_junior - 1 + NP_1 * 2 - 1], f)]
        x_p_best = xx_list[index_of_X_best(xx_list[max(D_junior - 1, 0): D_junior - 1 + NP_1 - 1], f)]
        if f(xx_list[i]) > f(xx_list[r_list]):
            v_delta = gpu.add(xx_list[i],
                             k_f * gpu.add(gpu.subtract(x_p_best, x_p_worst),
                                          gpu.subtract(xx_list[r_list], xx_list[i])))
        else:
            v_delta = gpu.add(xx_list[i],
                             k_f * gpu.add(gpu.subtract(x_p_best, x_p_worst),
                                          gpu.subtract(xx_list[i], xx_list[r_list])))
    else:
        v_delta = xx_list[i]
    return v_delta

# %%
def GSK(f):
    """
    DE algorithm
    :param x_list:
    :return: best x by DE
    """
    xxx_list = copy.deepcopy(X_list)

    x_best = xxx_list[0]
    # print(xxx_list[0])
    G = 0

    while G <= T_GSK:  # iteration of DE
        D_junior = int(NP * pow((1 - G / T_GSK), K))

        for i in range(NP):  # iteration of generation

            u_best = np.empty([Dim])
            for j in range(Dim):
                vj = np.empty([Dim])
                r = random.randint(0, NP - 1)
                if j <= D_junior:
                    vj = junior(xxx_list, r, j, f)
                else:
                    vj = senior(xxx_list, j, D_junior, f)

                vj = compare_max(vj)
                vj = compare_min(vj)

                if j == 0:
                    u_best = vj
                else:
                    u_best = select_better_fit(u_best, vj, f)

                if f(u_best) <= f(xxx_list[i]) and feas(u_best) == 1:
                    xxx_list[i] = u_best

                if f(xxx_list[i]) < f(x_best) and feas(xxx_list[i]) == 1:
                    x_best = xxx_list[i]

        G += 1

    return x_best

# %%
import os
i = 0
test_list = np.empty([len(functions.all_functions), 3])
test_path = r'D:\profile\codes\python_projects\ocp\test\output\D10'
for i in range(51):
    for f in functions.all_functions:
        x_best_DE_fit = 0
        x_best_AGDE_fit = 0
        x_best_GSK_fit = 0
        x_best_DE_fit = f(DE(f))
        x_best_AGDE_fit = f(AGDE(f))
        x_best_GSK_fit = f(GSK(f))
        print(f.__name__, x_best_DE_fit, x_best_AGDE_fit, x_best_GSK_fit, "\n")
        test_list[i][0] = x_best_DE_fit
        test_list[i][1] = x_best_AGDE_fit
        test_list[i][2] = x_best_GSK_fit
        i += 1
    np.savetxt(os.path.join(test_path, str(i) + ".txt"), test_list)
# Out:
# C:\Users\chris\AppData\Roaming\Python\Python39\site-packages\numba\cuda\compiler.py:726: NumbaPerformanceWarning: Grid size (1) < 2 * SM count (60) will likely result in GPU under utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))
# C:\Users\chris\AppData\Roaming\Python\Python39\site-packages\numba\cuda\cudadrv\devicearray.py:885: NumbaPerformanceWarning: Host array used in CUDA kernel will incur copy overhead to/from device.
#   warn(NumbaPerformanceWarning(msg))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-32147f3bd1a2> in <module>
#       9         x_best_GSK_fit = 0
#      10         x_best_DE_fit = f(DE(f))
# ---> 11         x_best_AGDE_fit = f(AGDE(f))
#      12         x_best_GSK_fit = f(GSK(f))
#      13         print(f.__name__, x_best_DE_fit, x_best_AGDE_fit, x_best_GSK_fit, "\n")
#
# <ipython-input-56-80a348372c39> in AGDE(f)
#      29                 vj = agde(xx_list, agde_F, p_j, f)
#      30                 vj = compare_max(vj)
# ---> 31                 vj = compare_min(vj)
#      32                 if random.uniform(0, 1) < Cr or j == j_random:
#      33                     u_j = crossover_SBX(xx_list[i], vj, f)
#
# <ipython-input-55-1cdbd523c0f6> in compare_min(delta)
#      33 def compare_min(delta):
#      34     on = np.linspace(100, 100, Dim)
# ---> 35     delta = gpu.minimum(delta, on)
#      36     # for i in range(len(delta)):
#      37     #     delta[i] = min(delta[i], 1)
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy_gpu\ops\minimum.py in minimum(a, b)
#      18
#      19     grid, block = get_grid_1d(a.size)
# ---> 20     _gpu_minimum[grid, block](flatten(a), flatten(b), flatten(c))
#      21
#      22     return c
#
# ~\AppData\Roaming\Python\Python39\site-packages\numba\cuda\compiler.py in __getitem__(self, args)
#     860         if len(args) not in [2, 3, 4]:
#     861             raise ValueError('must specify at least the griddim and blockdim')
# --> 862         return self.configure(*args)
#     863
#     864     def forall(self, ntasks, tpb=0, stream=0, sharedmem=0):
#
# ~\AppData\Roaming\Python\Python39\site-packages\numba\cuda\compiler.py in configure(self, griddim, blockdim, stream, sharedmem)
#     855     def configure(self, griddim, blockdim, stream=0, sharedmem=0):
#     856         griddim, blockdim = normalize_kernel_dimensions(griddim, blockdim)
# --> 857         return _KernelConfiguration(self, griddim, blockdim, stream, sharedmem)
#     858
#     859     def __getitem__(self, args):
#
# ~\AppData\Roaming\Python\Python39\site-packages\numba\cuda\compiler.py in __init__(self, dispatcher, griddim, blockdim, stream, sharedmem)
#     724                        "to low occupancy.")
#     725                 msg = msg.format(grid=grid_size, sm=2 * smcount)
# --> 726                 warn(NumbaPerformanceWarning(msg))
#     727
#     728     def __call__(self, *args):
#
# ~\AppData\Roaming\Python\Python39\site-packages\numba\core\errors.py in __init__(self, msg, loc, highlighting)
#      38                 highlight("%s\n%s\n" % (msg, loc.strformat())))
#      39         else:
# ---> 40             super(NumbaWarning, self).__init__(highlight("%s" % (msg,)))
#      41
#      42
#
# ~\AppData\Roaming\Python\Python39\site-packages\numba\core\errors.py in errmsg(self, msg)
#     315
#     316         def errmsg(self, msg):
# --> 317             return self._markup(msg, self._errmsg)
#     318
#     319         def filename(self, msg):
#
# ~\AppData\Roaming\Python\Python39\site-packages\numba\core\errors.py in _markup(self, msg, color, style)
#     305             if style:
#     306                 features += style
# --> 307             with ColorShell():
#     308                 with reset_terminal() as mu:
#     309                     mu += features.encode('utf-8')
#
# ~\AppData\Roaming\Python\Python39\site-packages\numba\core\errors.py in __init__(self)
#     223
#     224         def __init__(self):
# --> 225             init()
#     226             self._has_initialized = True
#     227
#
# c:\users\chris\appdata\local\programs\python\python39\lib\site-packages\colorama\initialise.py in init(autoreset, convert, strip, wrap)
#      36     else:
#      37         sys.stdout = wrapped_stdout = \
# ---> 38             wrap_stream(orig_stdout, convert, strip, autoreset, wrap)
#      39     if sys.stderr is None:
#      40         wrapped_stderr = None
#
# c:\users\chris\appdata\local\programs\python\python39\lib\site-packages\colorama\initialise.py in wrap_stream(stream, convert, strip, autoreset, wrap)
#      74 def wrap_stream(stream, convert, strip, autoreset, wrap):
#      75     if wrap:
# ---> 76         wrapper = AnsiToWin32(stream,
#      77             convert=convert, strip=strip, autoreset=autoreset)
#      78         if wrapper.should_wrap():
#
# c:\users\chris\appdata\local\programs\python\python39\lib\site-packages\colorama\ansitowin32.py in __init__(self, wrapped, convert, strip, autoreset)
#      86         # (e.g. Cygwin Terminal). In this case it's up to the terminal
#      87         # to support the ANSI codes.
# ---> 88         conversion_supported = on_windows and winapi_test()
#      89
#      90         # should we strip ANSI sequences from our output?
#
# c:\users\chris\appdata\local\programs\python\python39\lib\site-packages\colorama\win32.py in winapi_test()
#      97
#      98     def winapi_test():
# ---> 99         return any(_winapi_test(h) for h in
#     100                    (_GetStdHandle(STDOUT), _GetStdHandle(STDERR)))
#     101
#
# c:\users\chris\appdata\local\programs\python\python39\lib\site-packages\colorama\win32.py in <genexpr>(.0)
#      97
#      98     def winapi_test():
# ---> 99         return any(_winapi_test(h) for h in
#     100                    (_GetStdHandle(STDOUT), _GetStdHandle(STDERR)))
#     101
#
# c:\users\chris\appdata\local\programs\python\python39\lib\site-packages\colorama\win32.py in _winapi_test(handle)
#      92     def _winapi_test(handle):
#      93         csbi = CONSOLE_SCREEN_BUFFER_INFO()
# ---> 94         success = _GetConsoleScreenBufferInfo(
#      95             handle, byref(csbi))
#      96         return bool(success)
#
# KeyboardInterrupt:

# %%
import cec2017.utils as utils
for f in functions.all_functions:
    utils.surface_plot(f, points=120, dimension=Dim)
